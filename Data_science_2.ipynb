# %% [markdown]
# <a href="https://colab.research.google.com/github/MatiasMala/Entrega-1/blob/main/Data_science_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
url = 'https://raw.githubusercontent.com/MatiasMala/Entrega-1/main/laboratoria_salud%204.csv'
df = pd.read_csv(url, sep=';', encoding='latin-1')
df.head(10)
# Out:
#   fec_ocurrencia  edad sexo estado_civil desc_producto_agrupado  \
# 0       5/7/2018  48.0    F            C                    EPS
# 1       2/1/2016  83.0    M            C                    EPS
# 2       2/1/2016  73.0    F            C                    EPS
# 3       2/1/2016  72.0    F            C                    AMC
# 4       2/1/2016  82.0    F            C                    EPS
# 5       2/1/2016  87.0    F            C                    EPS
# 6       2/1/2016  49.0    M            C                    EPS
# 7       2/1/2016  69.0    M            C                    EPS
# 8       2/1/2016  53.0    M            C                    EPS
# 9       3/1/2016  51.0    M            C                    EPS
#
#   ind_capital_provincia         desc_tipo_contrat          agrupbenef  \
# 0                     E         PAGO POR SERVICIO         AMBULATORIO
# 1                     L      PACIENTE MES REGULAR         AMBULATORIO
# 2                     L      PACIENTE MES REGULAR         AMBULATORIO
# 3                     L         PAGO POR SERVICIO         AMBULATORIO
# 4                     L          PACIENTE MES HTA  PROGRAMAS CRONICOS
# 5                     L     PACIENTE MES DIABETES  PROGRAMAS CRONICOS
# 6                     L      PACIENTE MES REGULAR         AMBULATORIO
# 7                     L     PACIENTE MES DIABETES  PROGRAMAS CRONICOS
# 8                     L  PACIENTE MES DIABETES SP  PROGRAMAS CRONICOS
# 9                     L         PAGO POR SERVICIO        HOSPITALARIO
#
#   cod_diagnostico                   agrupdiagno  beneficio_pagado  \
# 0            I10X  HIPERTENSION ARTERIAL (N346)               146
# 1            I10X  HIPERTENSION ARTERIAL (N346)                79
# 2            E119      DIABETES MELLITUS (N166)               138
# 3            E119      DIABETES MELLITUS (N166)               246
# 4            I10X  HIPERTENSION ARTERIAL (N346)               120
# 5            E119      DIABETES MELLITUS (N166)               152
# 6            E119      DIABETES MELLITUS (N166)               100
# 7            E119      DIABETES MELLITUS (N166)               152
# 8            E119      DIABETES MELLITUS (N166)               290
# 9            I10X  HIPERTENSION ARTERIAL (N346)              1916
#
#    gasto_presentado  periodo    anio_ingreso   fecha_ingreso   agrup_CIE10  \
# 0                44     2018  No determinado  No determinado  Hipertension
# 1               620     2016  No determinado  No determinado  Hipertension
# 2               409     2016            2016        4/8/2016      Diabetes
# 3               308     2016  No determinado  No determinado      Diabetes
# 4               389     2016            2016        2/1/2016  Hipertension
# 5               188     2016            2016        2/1/2016      Diabetes
# 6               514     2016  No determinado  No determinado      Diabetes
# 7               524     2016            2016        2/1/2016      Diabetes
# 8               262     2016            2016        2/1/2016      Diabetes
# 9              2128     2016            2017       15/8/2017  Hipertension
#
#    flag_programa  num_afiliado
# 0              0          4359
# 1              0          1143
# 2              1          2159
# 3              0          8606
# 4              1          9510
# 5              1         10055
# 6              0         10059
# 7              1          9217
# 8              1         11745
# 9              1          1592

# %%
df.columns=['Fecha de Ocurrencia','Edad','Sexo','Estado Civil','Producto Agrupado','Donde Vive','Tipo de Contrato','Tipo de siniestro','Cod. Diagnostico','Desc. Diagnostico','Paga del asegurado','Costo del siniestro','Periodo','Año de ingreso','Fecha Ingreso','Tipo de enfermedad','Ingreso al programa','ID Afiliado']
df.head()
# Out:
#   Fecha de Ocurrencia  Edad Sexo Estado Civil Producto Agrupado Donde Vive  \
# 0            5/7/2018  48.0    F            C               EPS          E
# 1            2/1/2016  83.0    M            C               EPS          L
# 2            2/1/2016  73.0    F            C               EPS          L
# 3            2/1/2016  72.0    F            C               AMC          L
# 4            2/1/2016  82.0    F            C               EPS          L
#
#        Tipo de Contrato   Tipo de siniestro Cod. Diagnostico  \
# 0     PAGO POR SERVICIO         AMBULATORIO             I10X
# 1  PACIENTE MES REGULAR         AMBULATORIO             I10X
# 2  PACIENTE MES REGULAR         AMBULATORIO             E119
# 3     PAGO POR SERVICIO         AMBULATORIO             E119
# 4      PACIENTE MES HTA  PROGRAMAS CRONICOS             I10X
#
#               Desc. Diagnostico  Paga del asegurado  Costo del siniestro  \
# 0  HIPERTENSION ARTERIAL (N346)                 146                   44
# 1  HIPERTENSION ARTERIAL (N346)                  79                  620
# 2      DIABETES MELLITUS (N166)                 138                  409
# 3      DIABETES MELLITUS (N166)                 246                  308
# 4  HIPERTENSION ARTERIAL (N346)                 120                  389
#
#    Periodo  Año de ingreso   Fecha Ingreso Tipo de enfermedad  \
# 0     2018  No determinado  No determinado       Hipertension
# 1     2016  No determinado  No determinado       Hipertension
# 2     2016            2016        4/8/2016           Diabetes
# 3     2016  No determinado  No determinado           Diabetes
# 4     2016            2016        2/1/2016       Hipertension
#
#    Ingreso al programa  ID Afiliado
# 0                    0         4359
# 1                    0         1143
# 2                    1         2159
# 3                    0         8606
# 4                    1         9510

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18757 entries, 0 to 18756
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Fecha de Ocurrencia  18757 non-null  object
#  1   Edad                 18646 non-null  float64
#  2   Sexo                 18646 non-null  object
#  3   Estado Civil         17866 non-null  object
#  4   Producto Agrupado    18757 non-null  object
#  5   Donde Vive           18743 non-null  object
#  6   Tipo de Contrato     18757 non-null  object
#  7   Tipo de siniestro    18757 non-null  object
#  8   Cod. Diagnostico     18757 non-null  object
#  9   Desc. Diagnostico    18757 non-null  object
#  10  Paga del asegurado   18757 non-null  int64
#  11  Costo del siniestro  18757 non-null  int64
#  12  Periodo              18757 non-null  int64
#  13  Año de ingreso       18757 non-null  object
#  14  Fecha Ingreso        18757 non-null  object
#  15  Tipo de enfermedad   18757 non-null  object
#  16  Ingreso al programa  18757 non-null  int64
#  17  ID Afiliado          18757 non-null  int64
# dtypes: float64(1), int64(5), object(12)
# memory usage: 2.6+ MB

# %%
print(f'The Dataset has {df.duplicated().sum()} row duplicates')
# Out:
# The Dataset has 4 row duplicates

# %%
df.drop_duplicates()
# Out:
#       Fecha de Ocurrencia  Edad Sexo Estado Civil Producto Agrupado  \
# 0                5/7/2018  48.0    F            C               EPS
# 1                2/1/2016  83.0    M            C               EPS
# 2                2/1/2016  73.0    F            C               EPS
# 3                2/1/2016  72.0    F            C               AMC
# 4                2/1/2016  82.0    F            C               EPS
# ...                   ...   ...  ...          ...               ...
# 18752          10/12/2018  54.0    F          NaN               AMC
# 18753          27/12/2018  74.0    M          NaN               AMC
# 18754          27/12/2018  71.0    M          NaN               AMC
# 18755           20/8/2016  72.0    F          NaN               AMI
# 18756           23/3/2018  77.0    M          NaN               AMC
#
#       Donde Vive      Tipo de Contrato   Tipo de siniestro Cod. Diagnostico  \
# 0              E     PAGO POR SERVICIO         AMBULATORIO             I10X
# 1              L  PACIENTE MES REGULAR         AMBULATORIO             I10X
# 2              L  PACIENTE MES REGULAR         AMBULATORIO             E119
# 3              L     PAGO POR SERVICIO         AMBULATORIO             E119
# 4              L      PACIENTE MES HTA  PROGRAMAS CRONICOS             I10X
# ...          ...                   ...                 ...              ...
# 18752          P  PACIENTE MES REGULAR         AMBULATORIO             E119
# 18753          P     PAGO POR SERVICIO         AMBULATORIO             E119
# 18754          P  PACIENTE MES REGULAR         AMBULATORIO             E118
# 18755        NaN  PACIENTE MES REGULAR         AMBULATORIO             E119
# 18756        NaN     PAGO POR SERVICIO         AMBULATORIO             E119
#
#                   Desc. Diagnostico  Paga del asegurado  Costo del siniestro  \
# 0      HIPERTENSION ARTERIAL (N346)                 146                   44
# 1      HIPERTENSION ARTERIAL (N346)                  79                  620
# 2          DIABETES MELLITUS (N166)                 138                  409
# 3          DIABETES MELLITUS (N166)                 246                  308
# 4      HIPERTENSION ARTERIAL (N346)                 120                  389
# ...                             ...                 ...                  ...
# 18752      DIABETES MELLITUS (N166)                 247                 1609
# 18753      DIABETES MELLITUS (N166)                 231                  308
# 18754      DIABETES MELLITUS (N166)              744071                  200
# 18755      DIABETES MELLITUS (N166)              524538                  167
# 18756      DIABETES MELLITUS (N166)                 383                  425
#
#        Periodo  Año de ingreso   Fecha Ingreso Tipo de enfermedad  \
# 0         2018  No determinado  No determinado       Hipertension
# 1         2016  No determinado  No determinado       Hipertension
# 2         2016            2016        4/8/2016           Diabetes
# 3         2016  No determinado  No determinado           Diabetes
# 4         2016            2016        2/1/2016       Hipertension
# ...        ...             ...             ...                ...
# 18752     2018  No determinado  No determinado           Diabetes
# 18753     2018  No determinado  No determinado           Diabetes
# 18754     2018  No determinado  No determinado           Diabetes
# 18755     2016  No determinado  No determinado           Diabetes
# 18756     2018  No determinado  No determinado           Diabetes
#
#        Ingreso al programa  ID Afiliado
# 0                        0         4359
# 1                        0         1143
# 2                        1         2159
# 3                        0         8606
# 4                        1         9510
# ...                    ...          ...
# 18752                    0         2734
# 18753                    0         2738
# 18754                    0         7733
# 18755                    0        12121
# 18756                    0         2246
#
# [18753 rows x 18 columns]

# %%
df.describe()
# Out:
#                  Fecha de Ocurrencia          Edad  Paga del asegurado  \
# count                          18757  18646.000000        1.875700e+04
# mean   2017-07-21 08:51:52.310070784     63.006650        8.316168e+04
# min              2016-01-02 00:00:00      4.000000        0.000000e+00
# 25%              2016-10-25 00:00:00     54.000000        1.210000e+02
# 50%              2017-07-26 00:00:00     63.000000        2.010000e+02
# 75%              2018-04-30 00:00:00     72.000000        2.910000e+02
# max              2018-12-31 00:00:00    107.000000        1.964642e+07
# std                              NaN     14.036751        3.956779e+05
#
#        Costo del siniestro       Periodo  Ingreso al programa   ID Afiliado
# count         18757.000000  18757.000000         18757.000000  18757.000000
# mean            376.797995   2017.054593             0.577225   5617.073039
# min               0.000000   2016.000000             0.000000      1.000000
# 25%             155.000000   2016.000000             0.000000   2488.000000
# 50%             299.000000   2017.000000             1.000000   5344.000000
# 75%             492.000000   2018.000000             1.000000   8519.000000
# max           14207.000000   2018.000000             1.000000  12605.000000
# std             377.826489      0.814996             0.494014   3565.327357

# %%
df['Fecha de Ocurrencia'] = pd.to_datetime(df['Fecha de Ocurrencia'], format='mixed')
df.head()
# Out:
#   Fecha de Ocurrencia  Edad Sexo Estado Civil Producto Agrupado Donde Vive  \
# 0          2018-05-07  48.0    F            C               EPS          E
# 1          2016-02-01  83.0    M            C               EPS          L
# 2          2016-02-01  73.0    F            C               EPS          L
# 3          2016-02-01  72.0    F            C               AMC          L
# 4          2016-02-01  82.0    F            C               EPS          L
#
#        Tipo de Contrato   Tipo de siniestro Cod. Diagnostico  \
# 0     PAGO POR SERVICIO         AMBULATORIO             I10X
# 1  PACIENTE MES REGULAR         AMBULATORIO             I10X
# 2  PACIENTE MES REGULAR         AMBULATORIO             E119
# 3     PAGO POR SERVICIO         AMBULATORIO             E119
# 4      PACIENTE MES HTA  PROGRAMAS CRONICOS             I10X
#
#               Desc. Diagnostico  Paga del asegurado  Costo del siniestro  \
# 0  HIPERTENSION ARTERIAL (N346)                 146                   44
# 1  HIPERTENSION ARTERIAL (N346)                  79                  620
# 2      DIABETES MELLITUS (N166)                 138                  409
# 3      DIABETES MELLITUS (N166)                 246                  308
# 4  HIPERTENSION ARTERIAL (N346)                 120                  389
#
#    Periodo  Año de ingreso   Fecha Ingreso Tipo de enfermedad  \
# 0     2018  No determinado  No determinado       Hipertension
# 1     2016  No determinado  No determinado       Hipertension
# 2     2016            2016        4/8/2016           Diabetes
# 3     2016  No determinado  No determinado           Diabetes
# 4     2016            2016        2/1/2016       Hipertension
#
#    Ingreso al programa  ID Afiliado
# 0                    0         4359
# 1                    0         1143
# 2                    1         2159
# 3                    0         8606
# 4                    1         9510

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18757 entries, 0 to 18756
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Fecha de Ocurrencia  18757 non-null  datetime64[ns]
#  1   Edad                 18646 non-null  float64
#  2   Sexo                 18646 non-null  object
#  3   Estado Civil         17866 non-null  object
#  4   Producto Agrupado    18757 non-null  object
#  5   Donde Vive           18743 non-null  object
#  6   Tipo de Contrato     18757 non-null  object
#  7   Tipo de siniestro    18757 non-null  object
#  8   Cod. Diagnostico     18757 non-null  object
#  9   Desc. Diagnostico    18757 non-null  object
#  10  Paga del asegurado   18757 non-null  int64
#  11  Costo del siniestro  18757 non-null  int64
#  12  Periodo              18757 non-null  int64
#  13  Año de ingreso       18757 non-null  object
#  14  Fecha Ingreso        18757 non-null  object
#  15  Tipo de enfermedad   18757 non-null  object
#  16  Ingreso al programa  18757 non-null  int64
#  17  ID Afiliado          18757 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(5), object(11)
# memory usage: 2.6+ MB

# %%
vars_demograficas= ['ID Afiliado', 'Edad', 'Sexo', 'Estado Civil','Producto Agrupado', 'Donde Vive','Tipo de Contrato','Tipo de siniestro','Desc. Diagnostico','Tipo de enfermedad','Ingreso al programa']
df1 = df[vars_demograficas].drop_duplicates()
df1.head(10)
# Out:
#    ID Afiliado  Edad Sexo Estado Civil Producto Agrupado Donde Vive  \
# 0         4359  48.0    F            C               EPS          E
# 1         1143  83.0    M            C               EPS          L
# 2         2159  73.0    F            C               EPS          L
# 3         8606  72.0    F            C               AMC          L
# 4         9510  82.0    F            C               EPS          L
# 5        10055  87.0    F            C               EPS          L
# 6        10059  49.0    M            C               EPS          L
# 7         9217  69.0    M            C               EPS          L
# 8        11745  53.0    M            C               EPS          L
# 9         1592  51.0    M            C               EPS          L
#
#            Tipo de Contrato   Tipo de siniestro             Desc. Diagnostico  \
# 0         PAGO POR SERVICIO         AMBULATORIO  HIPERTENSION ARTERIAL (N346)
# 1      PACIENTE MES REGULAR         AMBULATORIO  HIPERTENSION ARTERIAL (N346)
# 2      PACIENTE MES REGULAR         AMBULATORIO      DIABETES MELLITUS (N166)
# 3         PAGO POR SERVICIO         AMBULATORIO      DIABETES MELLITUS (N166)
# 4          PACIENTE MES HTA  PROGRAMAS CRONICOS  HIPERTENSION ARTERIAL (N346)
# 5     PACIENTE MES DIABETES  PROGRAMAS CRONICOS      DIABETES MELLITUS (N166)
# 6      PACIENTE MES REGULAR         AMBULATORIO      DIABETES MELLITUS (N166)
# 7     PACIENTE MES DIABETES  PROGRAMAS CRONICOS      DIABETES MELLITUS (N166)
# 8  PACIENTE MES DIABETES SP  PROGRAMAS CRONICOS      DIABETES MELLITUS (N166)
# 9         PAGO POR SERVICIO        HOSPITALARIO  HIPERTENSION ARTERIAL (N346)
#
#   Tipo de enfermedad  Ingreso al programa
# 0       Hipertension                    0
# 1       Hipertension                    0
# 2           Diabetes                    1
# 3           Diabetes                    0
# 4       Hipertension                    1
# 5           Diabetes                    1
# 6           Diabetes                    0
# 7           Diabetes                    1
# 8           Diabetes                    1
# 9       Hipertension                    1

# %%
df1.shape
# Out:
# (14442, 11)

# %%
df1.isna().sum()
# Out:
# ID Afiliado              0
# Edad                    93
# Sexo                    93
# Estado Civil           723
# Producto Agrupado        0
# Donde Vive              14
# Tipo de Contrato         0
# Tipo de siniestro        0
# Desc. Diagnostico        0
# Tipo de enfermedad       0
# Ingreso al programa      0
# dtype: int64

# %%
df1['ID Afiliado'].value_counts()
# Out:
# ID Afiliado
# 665      5
# 1059     4
# 2858     4
# 1324     4
# 294      4
#         ..
# 9395     1
# 9839     1
# 10039    1
# 11592    1
# 12121    1
# Name: count, Length: 12605, dtype: int64

# %%
df1['Sexo']=df1['Sexo'].astype('category')
df1['Estado Civil']=df1['Estado Civil'].astype('category')
df1['Producto Agrupado']=df1['Producto Agrupado'].astype('category')
df1['Tipo de Contrato']=df1['Tipo de Contrato'].astype('category')
df1['Tipo de siniestro']=df1['Tipo de siniestro'].astype('category')
df1['Desc. Diagnostico']=df1['Desc. Diagnostico'].astype('category')
df1['Tipo de enfermedad']=df1['Tipo de enfermedad'].astype('category')

# %%
df1['Estado Civil'] = df1.groupby('ID Afiliado')['Estado Civil'].transform(lambda y: y.ffill())
df1['Donde Vive'] = df1.groupby('ID Afiliado')['Donde Vive'].transform(lambda y: y.ffill())
df1['Edad'] = df1.groupby('ID Afiliado')['Edad'].transform(lambda y: y.ffill())
df1['Sexo'] = df1.groupby('ID Afiliado')['Sexo'].transform(lambda y: y.ffill())
# Out:
# <ipython-input-73-eb9bbdfb3e9d>:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df1['Donde Vive'] = df1.groupby('ID Afiliado')['Donde Vive'].transform(lambda y: y.ffill())

# %%
df1 = df1.drop_duplicates(subset=['ID Afiliado'], keep='last')

# %%
df1.loc[df1['ID Afiliado']==665]
# Out:
#       ID Afiliado  Edad Sexo Estado Civil Producto Agrupado Donde Vive  \
# 8733          665  59.0    M            C               EPS          L
#
#          Tipo de Contrato   Tipo de siniestro             Desc. Diagnostico  \
# 8733  PACIENTE MES HTA SP  PROGRAMAS CRONICOS  HIPERTENSION ARTERIAL (N346)
#
#      Tipo de enfermedad  Ingreso al programa
# 8733       Hipertension                    1

# %%
df1['ID Afiliado'].value_counts()
# Out:
# ID Afiliado
# 1143     1
# 3908     1
# 10112    1
# 11240    1
# 308      1
#         ..
# 1405     1
# 3308     1
# 5620     1
# 8126     1
# 2246     1
# Name: count, Length: 12605, dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12605 entries, 1 to 18756
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID Afiliado          12605 non-null  int64
#  1   Edad                 12533 non-null  float64
#  2   Sexo                 12533 non-null  category
#  3   Estado Civil         11995 non-null  category
#  4   Producto Agrupado    12605 non-null  category
#  5   Donde Vive           12597 non-null  object
#  6   Tipo de Contrato     12605 non-null  category
#  7   Tipo de siniestro    12605 non-null  category
#  8   Desc. Diagnostico    12605 non-null  category
#  9   Tipo de enfermedad   12605 non-null  category
#  10  Ingreso al programa  12605 non-null  int64
# dtypes: category(7), float64(1), int64(2), object(1)
# memory usage: 579.9+ KB

# %%
df2=df1.groupby(['Tipo de enfermedad'])['Edad'].median().reset_index()
df2
# Out:
# <ipython-input-78-81cfc32931c7>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df2=df1.groupby(['Tipo de enfermedad'])['Edad'].median().reset_index()
#   Tipo de enfermedad  Edad
# 0           Diabetes  61.0
# 1       Hipertension  63.0

# %%
mapping_dict = df2.set_index('Tipo de enfermedad')['Edad'].to_dict()
mapping_dict
# Out:
# {'Diabetes': 61.0, 'Hipertension': 63.0}

# %%
df1['Filled Edad'] = df1['Tipo de enfermedad'].map(mapping_dict)
df1.head()
# Out:
#    ID Afiliado  Edad Sexo Estado Civil Producto Agrupado Donde Vive  \
# 1         1143  83.0    M            C               EPS          L
# 3         8606  72.0    F            C               AMC          L
# 4         9510  82.0    F            C               EPS          L
# 6        10059  49.0    M            C               EPS          L
# 7         9217  69.0    M            C               EPS          L
#
#         Tipo de Contrato   Tipo de siniestro             Desc. Diagnostico  \
# 1   PACIENTE MES REGULAR         AMBULATORIO  HIPERTENSION ARTERIAL (N346)
# 3      PAGO POR SERVICIO         AMBULATORIO      DIABETES MELLITUS (N166)
# 4       PACIENTE MES HTA  PROGRAMAS CRONICOS  HIPERTENSION ARTERIAL (N346)
# 6   PACIENTE MES REGULAR         AMBULATORIO      DIABETES MELLITUS (N166)
# 7  PACIENTE MES DIABETES  PROGRAMAS CRONICOS      DIABETES MELLITUS (N166)
#
#   Tipo de enfermedad  Ingreso al programa Filled Edad
# 1       Hipertension                    0        63.0
# 3           Diabetes                    0        61.0
# 4       Hipertension                    1        63.0
# 6           Diabetes                    0        61.0
# 7           Diabetes                    1        61.0

# %%
df1['Filled Edad'] = df1['Filled Edad'].astype('float')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12605 entries, 1 to 18756
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID Afiliado          12605 non-null  int64
#  1   Edad                 12533 non-null  float64
#  2   Sexo                 12533 non-null  category
#  3   Estado Civil         11995 non-null  category
#  4   Producto Agrupado    12605 non-null  category
#  5   Donde Vive           12597 non-null  object
#  6   Tipo de Contrato     12605 non-null  category
#  7   Tipo de siniestro    12605 non-null  category
#  8   Desc. Diagnostico    12605 non-null  category
#  9   Tipo de enfermedad   12605 non-null  category
#  10  Ingreso al programa  12605 non-null  int64
#  11  Filled Edad          12605 non-null  float64
# dtypes: category(7), float64(2), int64(2), object(1)
# memory usage: 678.4+ KB

# %%
df1['Edad']=df1['Edad'].fillna(df1['Filled Edad'])
df1
# Out:
#        ID Afiliado  Edad Sexo Estado Civil Producto Agrupado Donde Vive  \
# 1             1143  83.0    M            C               EPS          L
# 3             8606  72.0    F            C               AMC          L
# 4             9510  82.0    F            C               EPS          L
# 6            10059  49.0    M            C               EPS          L
# 7             9217  69.0    M            C               EPS          L
# ...            ...   ...  ...          ...               ...        ...
# 18751         1630  72.0    M          NaN               AMC          P
# 18753         2738  74.0    M          NaN               AMC          P
# 18754         7733  71.0    M          NaN               AMC          P
# 18755        12121  72.0    F          NaN               AMI        NaN
# 18756         2246  77.0    M          NaN               AMC          P
#
#             Tipo de Contrato   Tipo de siniestro  \
# 1       PACIENTE MES REGULAR         AMBULATORIO
# 3          PAGO POR SERVICIO         AMBULATORIO
# 4           PACIENTE MES HTA  PROGRAMAS CRONICOS
# 6       PACIENTE MES REGULAR         AMBULATORIO
# 7      PACIENTE MES DIABETES  PROGRAMAS CRONICOS
# ...                      ...                 ...
# 18751      PAGO POR SERVICIO         AMBULATORIO
# 18753      PAGO POR SERVICIO         AMBULATORIO
# 18754   PACIENTE MES REGULAR         AMBULATORIO
# 18755   PACIENTE MES REGULAR         AMBULATORIO
# 18756      PAGO POR SERVICIO         AMBULATORIO
#
#                   Desc. Diagnostico Tipo de enfermedad  Ingreso al programa  \
# 1      HIPERTENSION ARTERIAL (N346)       Hipertension                    0
# 3          DIABETES MELLITUS (N166)           Diabetes                    0
# 4      HIPERTENSION ARTERIAL (N346)       Hipertension                    1
# 6          DIABETES MELLITUS (N166)           Diabetes                    0
# 7          DIABETES MELLITUS (N166)           Diabetes                    1
# ...                             ...                ...                  ...
# 18751      DIABETES MELLITUS (N166)           Diabetes                    0
# 18753      DIABETES MELLITUS (N166)           Diabetes                    0
# 18754      DIABETES MELLITUS (N166)           Diabetes                    0
# 18755      DIABETES MELLITUS (N166)           Diabetes                    0
# 18756      DIABETES MELLITUS (N166)           Diabetes                    0
#
#        Filled Edad
# 1             63.0
# 3             61.0
# 4             63.0
# 6             61.0
# 7             61.0
# ...            ...
# 18751         61.0
# 18753         61.0
# 18754         61.0
# 18755         61.0
# 18756         61.0
#
# [12605 rows x 12 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12605 entries, 1 to 18756
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID Afiliado          12605 non-null  int64
#  1   Edad                 12605 non-null  float64
#  2   Sexo                 12533 non-null  category
#  3   Estado Civil         11995 non-null  category
#  4   Producto Agrupado    12605 non-null  category
#  5   Donde Vive           12597 non-null  object
#  6   Tipo de Contrato     12605 non-null  category
#  7   Tipo de siniestro    12605 non-null  category
#  8   Desc. Diagnostico    12605 non-null  category
#  9   Tipo de enfermedad   12605 non-null  category
#  10  Ingreso al programa  12605 non-null  int64
#  11  Filled Edad          12605 non-null  float64
# dtypes: category(7), float64(2), int64(2), object(1)
# memory usage: 678.4+ KB

# %%
df1.drop(['Filled Edad'], axis=1, inplace=True)
df1
# Out:
#        ID Afiliado  Edad Sexo Estado Civil Producto Agrupado Donde Vive  \
# 1             1143  83.0    M            C               EPS          L
# 3             8606  72.0    F            C               AMC          L
# 4             9510  82.0    F            C               EPS          L
# 6            10059  49.0    M            C               EPS          L
# 7             9217  69.0    M            C               EPS          L
# ...            ...   ...  ...          ...               ...        ...
# 18751         1630  72.0    M          NaN               AMC          P
# 18753         2738  74.0    M          NaN               AMC          P
# 18754         7733  71.0    M          NaN               AMC          P
# 18755        12121  72.0    F          NaN               AMI        NaN
# 18756         2246  77.0    M          NaN               AMC          P
#
#             Tipo de Contrato   Tipo de siniestro  \
# 1       PACIENTE MES REGULAR         AMBULATORIO
# 3          PAGO POR SERVICIO         AMBULATORIO
# 4           PACIENTE MES HTA  PROGRAMAS CRONICOS
# 6       PACIENTE MES REGULAR         AMBULATORIO
# 7      PACIENTE MES DIABETES  PROGRAMAS CRONICOS
# ...                      ...                 ...
# 18751      PAGO POR SERVICIO         AMBULATORIO
# 18753      PAGO POR SERVICIO         AMBULATORIO
# 18754   PACIENTE MES REGULAR         AMBULATORIO
# 18755   PACIENTE MES REGULAR         AMBULATORIO
# 18756      PAGO POR SERVICIO         AMBULATORIO
#
#                   Desc. Diagnostico Tipo de enfermedad  Ingreso al programa
# 1      HIPERTENSION ARTERIAL (N346)       Hipertension                    0
# 3          DIABETES MELLITUS (N166)           Diabetes                    0
# 4      HIPERTENSION ARTERIAL (N346)       Hipertension                    1
# 6          DIABETES MELLITUS (N166)           Diabetes                    0
# 7          DIABETES MELLITUS (N166)           Diabetes                    1
# ...                             ...                ...                  ...
# 18751      DIABETES MELLITUS (N166)           Diabetes                    0
# 18753      DIABETES MELLITUS (N166)           Diabetes                    0
# 18754      DIABETES MELLITUS (N166)           Diabetes                    0
# 18755      DIABETES MELLITUS (N166)           Diabetes                    0
# 18756      DIABETES MELLITUS (N166)           Diabetes                    0
#
# [12603 rows x 11 columns]

# %%
df1['Estado Civil']=df1['Estado Civil'].fillna(df1['Estado Civil'].mode()[0])
df1['Sexo']=df1['Sexo'].fillna(df1['Sexo'].mode()[0])
df1['Donde Vive']=df1['Donde Vive'].fillna(df1['Donde Vive'].mode()[0])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12603 entries, 1 to 18756
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID Afiliado          12603 non-null  int64
#  1   Edad                 12603 non-null  float64
#  2   Sexo                 12603 non-null  category
#  3   Estado Civil         12603 non-null  category
#  4   Producto Agrupado    12603 non-null  category
#  5   Donde Vive           12603 non-null  object
#  6   Tipo de Contrato     12603 non-null  category
#  7   Tipo de siniestro    12603 non-null  category
#  8   Desc. Diagnostico    12603 non-null  category
#  9   Tipo de enfermedad   12603 non-null  category
#  10  Ingreso al programa  12603 non-null  int64
# dtypes: category(7), float64(1), int64(2), object(1)
# memory usage: 837.8+ KB

# %%
df1=df1.sort_values(by='ID Afiliado', ascending=True)
df1
# Out:
#        ID Afiliado   Edad Sexo Estado Civil Producto Agrupado Donde Vive  \
# 17426            1   43.0    F            S               EPS          P
# 3060             2  101.0    F            C               AMI          L
# 16749            3   57.0    F            S               AMI          L
# 975              4   58.0    M            C               EPS          L
# 5780             5   75.0    F            C               AMI          L
# ...            ...    ...  ...          ...               ...        ...
# 6758         12601   69.0    F            C               EPS          L
# 5646         12602   62.0    M            C               EPS          L
# 17189        12603   70.0    M            S               EPS          P
# 1461         12604   69.0    F            C               EPS          L
# 11818        12605   74.0    M            C               EPS          L
#
#            Tipo de Contrato   Tipo de siniestro             Desc. Diagnostico  \
# 17426     PAGO POR SERVICIO         AMBULATORIO  HIPERTENSION ARTERIAL (N346)
# 3060    PACIENTE MES HTA SP  PROGRAMAS CRONICOS  HIPERTENSION ARTERIAL (N346)
# 16749     PAGO POR SERVICIO         AMBULATORIO  HIPERTENSION ARTERIAL (N346)
# 975    PACIENTE MES REGULAR         AMBULATORIO      DIABETES MELLITUS (N166)
# 5780      PAGO POR SERVICIO         AMBULATORIO  HIPERTENSION ARTERIAL (N346)
# ...                     ...                 ...                           ...
# 6758    PACIENTE MES HTA SP  PROGRAMAS CRONICOS  HIPERTENSION ARTERIAL (N346)
# 5646   PACIENTE MES REGULAR         AMBULATORIO  HIPERTENSION ARTERIAL (N346)
# 17189  PACIENTE MES REGULAR         AMBULATORIO      DIABETES MELLITUS (N166)
# 1461    PACIENTE MES HTA SP  PROGRAMAS CRONICOS  HIPERTENSION ARTERIAL (N346)
# 11818   PACIENTE MES HTA SP  PROGRAMAS CRONICOS  HIPERTENSION ARTERIAL (N346)
#
#       Tipo de enfermedad  Ingreso al programa
# 17426       Hipertension                    0
# 3060        Hipertension                    1
# 16749       Hipertension                    1
# 975             Diabetes                    0
# 5780        Hipertension                    1
# ...                  ...                  ...
# 6758        Hipertension                    1
# 5646        Hipertension                    1
# 17189           Diabetes                    1
# 1461        Hipertension                    1
# 11818       Hipertension                    1
#
# [12603 rows x 11 columns]

# %%
plt.boxplot(df1['Edad'])
plt.title('Basic Boxplot')
plt.show()

# %%
#Calculate the percentiles
seventy_fifth = df1['Edad'].quantile(0.75)
twenty_fifth = df1['Edad'].quantile(0.25)
# Obtain IQR
iqr = seventy_fifth - twenty_fifth

# Upper and lower thresholds
upper = seventy_fifth + (1.5 * iqr)
lower = twenty_fifth - (1.5 * iqr)

# Subset the dataset
outliers = df1[(df1['Edad'] < lower) | (df1['Edad'] > upper)]
outliers.head()
# Out:
#        ID Afiliado   Edad Sexo Estado Civil Producto Agrupado Donde Vive  \
# 3060             2  101.0    F            C               AMI          L
# 16840           20   19.0    M            S               EPS          P
# 14009           47   21.0    M            S               EPS          L
# 15306          286   17.0    F            S               EPS          L
# 18027          287   17.0    F            C               AMC          L
#
#            Tipo de Contrato   Tipo de siniestro             Desc. Diagnostico  \
# 3060    PACIENTE MES HTA SP  PROGRAMAS CRONICOS  HIPERTENSION ARTERIAL (N346)
# 16840     PAGO POR SERVICIO         AMBULATORIO      DIABETES MELLITUS (N166)
# 14009     PAGO POR SERVICIO         AMBULATORIO      DIABETES MELLITUS (N166)
# 15306  PACIENTE MES REGULAR         AMBULATORIO      DIABETES MELLITUS (N166)
# 18027  PACIENTE MES REGULAR         AMBULATORIO      DIABETES MELLITUS (N166)
#
#       Tipo de enfermedad  Ingreso al programa
# 3060        Hipertension                    1
# 16840           Diabetes                    0
# 14009           Diabetes                    0
# 15306           Diabetes                    0
# 18027           Diabetes                    0

# %%
# Obtain number of outliers
print(f'Number of outliers: {len(outliers)}')
# Out:
# Number of outliers: 171
